# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.ticker import FixedLocator, LogLocator, LogFormatter, LogFormatterMathtext, NullFormatter

plt.rcParams['font.family'] = 'Nimbus Roman'
mpl.rcParams["text.usetex"] = True

# %% [markdown]
# # Data extraction

# %%
energy_per_omega_per_basis = {}
rij_init_time_per_omega_per_basis = {}
rij_per_iter_per_omega_per_basis = {}
xc_per_iter_per_omega_per_basis = {}

si_data_path = "/n/home02/hieudinh/rsdf_test_full_J/post_process/si_supercell"

for basis in ["ccpvdz"]:
    df = pd.read_csv(si_data_path + f"/data_{basis}_2.csv")

    cc_2e3c = df["2e3c-CC(s)"].astype(float).to_numpy()
    cd_2e3c = df["2e3c-CD(s)"].astype(float).to_numpy()
    sr_2e2c = df["2e2c(s)"].astype(float).to_numpy()
    rij_total_time = df["RIJ-BIGMEM(s)"].astype(float).to_numpy()
    xc_time = df["DFT-XC(s)"].astype(float).to_numpy()
    energy = df["Energy"].astype(float).to_numpy()
    niter = df["niter"].astype(float).to_numpy()
    
    supercell = df["Supercell"].astype(str).to_numpy()
    omega = df["Omega"].astype(str).to_numpy()

    rij_init_time = sr_2e2c +cc_2e3c + cd_2e3c 
    # Time per iteration for J build
    rij_per_iter = (rij_total_time - cc_2e3c - cd_2e3c - sr_2e2c) / niter
    # Time per iteration for XC
    xc_per_iter = xc_time / niter

    # Extract the data that belongs to similar range-separated omega value
    energy_per_omega = {}
    rij_init_time_per_omega = {}
    rij_per_iter_per_omega = {}
    xc_per_iter_per_omega = {}
    for w in range(len(omega)):
        key = omega[w]
        if key not in rij_init_time_per_omega:
            energy_per_omega[key] = []
            rij_init_time_per_omega[key] = []
            rij_per_iter_per_omega[key] = []
            xc_per_iter_per_omega[key] = []
        
        energy_per_omega[key].append(energy[w])
        rij_init_time_per_omega[key].append(rij_init_time[w])
        rij_per_iter_per_omega[key].append(rij_per_iter[w])
        xc_per_iter_per_omega[key].append(xc_per_iter[w])
        

    energy_per_omega_per_basis[basis] = energy_per_omega
    rij_init_time_per_omega_per_basis[basis] = rij_init_time_per_omega
    rij_per_iter_per_omega_per_basis[basis] = rij_per_iter_per_omega
    xc_per_iter_per_omega_per_basis[basis] = xc_per_iter_per_omega


# Extract the memeory requirement for storing the integral here
memory_per_omega_per_basis = {}
for basis in ["ccpvdz"]:
    df = pd.read_csv(si_data_path + f"/memory_{basis}_2.csv")
    
    static_mem = df["StaticMem(GB)"].astype(float).to_numpy()
    # Convert GiB to GB
    static_mem *= 1024 * 1024 * 1024
    static_mem /= 10**9
    
    memory_per_omega = {}

    omega = df["Omega"].astype(str).to_numpy() # Contain redundant omega
    
    for w in range(len(omega)):
        key = omega[w]
        if key not in memory_per_omega:
            memory_per_omega[key] = []
        
        memory_per_omega[key].append(static_mem[w])
    
    print(memory_per_omega)
    memory_per_omega_per_basis[basis] = memory_per_omega
# Out:
# {'0.3': [0.001073741824, 0.614180323328, 21.199958573056, 218.73731567616], '0.6': [0.001073741824, 0.581968068608, 19.96622921728, 202.417513693184], '0.9': [0.001073741824, 0.516469817344, 15.067819016191999, 131.60424040038401]}

# %% [markdown]
# # Plot run time vs number of atoms

# %%
# Plot the data
omega_vals = ['0.3', '0.6', '0.9']
omega_labels = ['o', 's', '^']
supercell = [2 * i * i * i for i in range(1,5)]
basis_series = ["ccpvdz"]
color_series = ["blue", "green", "red"]


fs = 20
ms = 12

# # Fitting to get the supercell size for each RI-J iteration
# coeffs_per_omega_per_basis = {}
# for ib in range(len(basis_series)):
#     basis = basis_series[ib]
    
#     coeffs_per_omega = {}
#     for idx in range(len(omega_vals)):
#         w = omega_vals[idx]
#         marker_type = omega_labels[idx]
#         time = rij_per_iter_per_omega_per_basis[basis][w]
                    
#         log_supercell = np.log(supercell[1:])
#         log_rij_per_iter = np.log(time[1:])
#         coeffs = np.polyfit(log_supercell, log_rij_per_iter, 1)
#         n = coeffs[0]      # scaling exponent
#         print("w = " + str(w) + " has n = " + str(n))
#         coeffs_per_omega[w] = coeffs
        
#     coeffs_per_omega_per_basis[basis] = coeffs_per_omega  

# RIJ per iteration
# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
# for ib in range(len(basis_series)):
#     basis = basis_series[ib]
    
#     for idx in range(len(omega_vals)):
        
#         colors = color_series[idx]
#         w = omega_vals[idx]
#         marker_type = omega_labels[idx]
#         ax.plot(supercell, rij_per_iter_per_omega_per_basis[basis][w], marker = marker_type, markersize=ms, color = colors, linestyle="None", label = rf"$\omega = {w}$")

#         # Plot the fitting line here
#         coeffs = coeffs_per_omega_per_basis[basis][w]
#         natom_fit = np.linspace(0.5 * 2**3, 4 * 4**3, 40)
#         time_per_iter_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]
        
#         ax.plot(natom_fit, time_per_iter_fit, color = colors, linestyle="--", linewidth= 3)
        
#     ax.set_xlabel(r"N$_\mathrm{atom}$", size = fs)
#     ax.set_ylabel(r"Wall time (s)", size = fs)
#     ax.tick_params(axis='both', which='both', direction='in', labelsize=fs, pad = 8)
#     ax.set_yscale('log')
#     ax.set_xscale('log')
    
#     ax.set_xlim([0.9, 250])
    
#     ax.tick_params(axis='both', which='both', direction='in', labelsize=fs)
#     ax.tick_params(axis='y', which='major', length=5, width=1.5)
#     ax.tick_params(axis='y', which='minor', length=2.5, width=0.75)
    
#     ax.set_xticks([1, 10, 100])
#     ax.tick_params(axis='x', which='major', length=5, width=1.5)
#     ax.tick_params(axis='x', which='minor', length=2.5, width=0.75)
    

# Fitting to get the supercell size for each RI-J init time
coeffs_per_omega_per_basis = {}
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    coeffs_per_omega = {}
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        time = rij_init_time_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[2:])
        log_rij_per_iter = np.log(time[2:])
        coeffs = np.polyfit(log_supercell, log_rij_per_iter, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))
        coeffs_per_omega[w] = coeffs

    coeffs_per_omega_per_basis[basis] = coeffs_per_omega  

# RIJ init time vs supercell
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        colors = color_series[idx]
        marker_type = omega_labels[idx]
        ax.plot(supercell, rij_init_time_per_omega_per_basis[basis][w], marker = marker_type, color = colors, markersize=ms, linestyle="None", label = rf"$\omega = {w}$")
        
        # Plot the fitting line here
        coeffs = coeffs_per_omega_per_basis[basis][w]
        natom_fit = np.linspace(0.5 * 2**3, 4 * 4**3, 40)
        time_per_iter_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]
        
        ax.plot(natom_fit, time_per_iter_fit, color = colors, linestyle="--", linewidth= 3)
        
    ax.set_xlabel(r"N$_\mathrm{atom}$", size = fs)
    ax.set_ylabel(r"Wall time (s)", size = fs)
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs, pad = 8)
    ax.set_yscale('log')
    ax.set_xscale('log')
    
    ax.set_xlim([0.9, 250])
    
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs)
    ax.tick_params(axis='y', which='major', length=5, width=1.5)
    ax.tick_params(axis='y', which='minor', length=2.5, width=0.75)
    
    ax.set_xticks([1, 10, 100])
    ax.tick_params(axis='x', which='major', length=5, width=1.5)
    ax.tick_params(axis='x', which='minor', length=2.5, width=0.75)
    

marker_handles = handles=[
    Line2D([0], [0], marker=omega_labels[0], color=color_series[0], markersize = ms, linestyle='None', label=r'$\omega$ = 0.3'),
    Line2D([0], [0], marker=omega_labels[1], color=color_series[1], markersize = ms, linestyle='None', label=r'$\omega$ = 0.6'),
    Line2D([0], [0], marker=omega_labels[2], color=color_series[2], markersize = ms, linestyle='None', label=r'$\omega$ = 0.9')]

# global marker legend beneath both plots
# fig.legend(handles=marker_handles,
#            loc='lower center',
#            bbox_to_anchor=(0.5, -0.1),   # adjust vertical offset
#            fontsize=fs,
#            ncol=3)

# handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.08), fontsize=18, ncol=3)
# plt.show()


# # XC per iteration
# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))
# for ib in range(len(basis_series)):
#     basis = basis_series[ib]
    
#     for idx in range(len(omega_vals)):
#         w = omega_vals[idx]
#         marker_type = omega_labels[idx]
#         ax.plot(supercell, xc_per_iter_per_omega_per_basis[basis][w], marker = marker_type, markersize=10, linestyle="--", label = rf"$\omega = {w}$")

#     ax.set_xlabel(r"$Supercell$", size = 18)
#     ax.set_ylabel(r"Wall time (s)", size = 18)
#     ax.tick_params(axis='both', which='both', direction='in', labelsize=14)
#     ax.set_yscale('log')
#     ax.set_xscale('log')
#     # ax[ib].legend()
# handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.08), fontsize=18, ncol=3)
# plt.show()
# Out:
# w = 0.3 has n = 2.6148707924889623
# w = 0.6 has n = 2.6424584734621113
# w = 0.9 has n = 2.6130748844012817

# %% [markdown]
# # Combine the RIJ init time and the RIJ per iteration time for plotting purpose

# %%
# Plot the data
omega_vals = ['0.3', '0.6', '0.9']
omega_labels = ['o', 's', '^']
supercell = [ 2 * i * i * i for i in range(1,5)]
basis_series = ["ccpvdz"]
color_series = ["blue", "green", "red"]

fs = 30
ms = 15

# Fitting to the supercell size for time per iter
print("Fit time per iter")
time_per_iter_coeffs_per_omega_per_basis = {}
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    coeffs_per_omega = {}
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        time = rij_per_iter_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[1:])
        log_rij_per_iter = np.log(time[1:])
        coeffs = np.polyfit(log_supercell, log_rij_per_iter, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))
        coeffs_per_omega[w] = coeffs
        
    time_per_iter_coeffs_per_omega_per_basis[basis] = coeffs_per_omega  

# Fitting to the supercell size for init time   
print("Fit init time")
init_time_coeffs_per_omega_per_basis = {}
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    coeffs_per_omega = {}
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        time = rij_init_time_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[1:])
        log_rij_per_iter = np.log(time[1:])
        coeffs = np.polyfit(log_supercell, log_rij_per_iter, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))
        coeffs_per_omega[w] = coeffs
        
    init_time_coeffs_per_omega_per_basis[basis] = coeffs_per_omega  
    
    
# RIJ per iteration
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
for plt_idx in range(2):
    
    for ib in range(len(basis_series)):
        basis = basis_series[ib]

        for idx in range(len(omega_vals)):
            w = omega_vals[idx]
            marker_type = omega_labels[idx]
            colors = color_series[idx]
            
            if plt_idx == 0:
                ax[plt_idx].plot(supercell, rij_per_iter_per_omega_per_basis[basis][w], color = colors, marker = marker_type, markersize = ms, linestyle="None", label = rf"$\omega = {w}$")
                # Plot the fitting line here
                coeffs = time_per_iter_coeffs_per_omega_per_basis[basis][w]
                natom_fit = np.linspace(0.5 * 2**3, 4 * 4**3, 40)
                time_per_iter_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]

                ax[plt_idx].plot(natom_fit, time_per_iter_fit, color = colors, linestyle="--", linewidth= 3)
                
            else:
                ax[plt_idx].plot(supercell, rij_init_time_per_omega_per_basis[basis][w], color = colors, marker = marker_type, markersize = ms, linestyle="None", label = rf"$\omega = {w}$")                
                
                # Plot the fitting line here
                coeffs = init_time_coeffs_per_omega_per_basis[basis][w]
                natom_fit = np.linspace(0.5 * 2**3, 4 * 4**3, 40)
                init_time_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]

                ax[plt_idx].plot(natom_fit, init_time_fit, color = colors, linestyle="--", linewidth= 3)
    
    
        ax[plt_idx].set_xlabel(r"N$_\mathrm{atom}$", size = fs, fontname="Nimbus Roman")
        ax[0].set_ylabel(r"Wall time (s)", size = fs, fontname="Nimbus Roman")
        ax[plt_idx].tick_params(axis='both', which='both', direction='in', labelsize=fs, pad = 10)
        ax[plt_idx].set_yscale('log')
        ax[plt_idx].set_xscale('log')
        
        ax[plt_idx].set_xticks([1, 10, 100])
        ax[plt_idx].tick_params(axis='x', which='major', length=5, width=1.5)
        

marker_handles = handles=[
    Line2D([0], [0], marker=omega_labels[0], color=color_series[0], markersize = ms, linestyle='None', label=r'$\omega$ = 0.3'),
    Line2D([0], [0], marker=omega_labels[1], color=color_series[1], markersize = ms, linestyle='None', label=r'$\omega$ = 0.6'),
    Line2D([0], [0], marker=omega_labels[2], color=color_series[2], markersize = ms, linestyle='None', label=r'$\omega$ = 0.9')]

# global marker legend beneath both plots
fig.legend(handles=marker_handles,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.15),   # adjust vertical offset
           fontsize=fs * 0.7,
           ncol=3)

        
# handles, labels = ax[0].get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.08), fontsize=18, ncol=3)
plt.show()

# # RIJ init time vs supercell
# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))
# for ib in range(len(basis_series)):
#     basis = basis_series[ib]
    
#     for idx in range(len(omega_vals)):
#         w = omega_vals[idx]
#         marker_type = omega_labels[idx]
#         ax.plot(supercell, rij_init_time_per_omega_per_basis[basis][w], marker = marker_type, markersize=10, linestyle="--", label = rf"$\omega = {w}$")

#     ax.set_xlabel(r"$Supercell$", size = 18)
#     ax.set_ylabel(r"Wall time (s)", size = 18)
#     ax.tick_params(axis='both', which='both', direction='in', labelsize=14)
#     ax.set_yscale('log')
#     ax.set_xscale('log')
#     # ax[ib].legend()
# handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.08), fontsize=18, ncol=3)
# plt.show()


# RIJ per iteration [Combine both line into one plot]
# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))

    
# for ib in range(len(basis_series)):
#     basis = basis_series[ib]

#     for idx in range(len(omega_vals)):
#         w = omega_vals[idx]
#         marker_type = omega_labels[idx]
#         colors = color_series[idx]
            
#         ax.plot(supercell, rij_per_iter_per_omega_per_basis[basis][w], color = colors, marker = marker_type, markersize = ms, linestyle="--", label = rf"$\omega = {w}$")
#         ax.plot(supercell, rij_init_time_per_omega_per_basis[basis][w], color = colors, marker = marker_type, markersize = ms, linestyle="-", label = rf"$\omega = {w}$")                
    
#     ax.set_xlabel(r"Supercell size", size = fs, fontname="Nimbus Roman")
#     ax.set_ylabel(r"Wall time (s)", size = fs, fontname="Nimbus Roman")
#     ax.tick_params(axis='both', which='both', direction='in', labelsize=fs)
#     ax.set_yscale('log')
#     ax.set_xscale('log')


# marker_legend = ax.legend(handles=[
#     Line2D([0], [0], marker=omega_labels[0], color=color_series[0], markersize = ms * 0.7, linestyle='None', label=r'$\omega$ = 0.3'),
#     Line2D([0], [0], marker=omega_labels[1], color=color_series[1], markersize = ms * 0.7, linestyle='None', label=r'$\omega$ = 0.6'),
#     Line2D([0], [0], marker=omega_labels[2], color=color_series[2], markersize = ms * 0.7, linestyle='None', label=r'$\omega$ = 0.9')
# ], loc='lower right', fontsize=fs * 0.7)


# handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.2), fontsize=18, ncol=3)
plt.show()
# Out:
# Fit time per iter
# w = 0.3 has n = 1.9245943205685307
# w = 0.6 has n = 1.6748752077598008
# w = 0.9 has n = 1.5505547347279929
# Fit init time
# w = 0.3 has n = 1.4998632047941451
# w = 0.6 has n = 1.6539592670666359
# w = 0.9 has n = 1.852905410009223

# %% [markdown]
# # Storage for the supercell

# %%
# Plot the data
omega_vals = ['0.3', '0.6', '0.9']
supercell = [i * i * i for i in range(1,5)]
omega_labels = ['o', 's', '^']
color_series = ["blue", "green", "red"]
basis_series = ["ccpvdz"]

fs = 30
ms = 15

# Fitting the storage data
for ib in range(len(basis_series)):
    basis = basis_series[ib]
        
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        storage = memory_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[1:])
        log_storage = np.log(storage[1:])
        coeffs = np.polyfit(log_supercell, log_storage, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))

# Converged energy at different omega
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        colors = color_series[idx]
        ax.plot(supercell, memory_per_omega_per_basis[basis][w], color = colors, marker = marker_type, markersize = ms, linestyle="None", label = rf"$\omega = {w}$")

    # ax[ib].set_title(f"Static memory requirement ({basis})", size = 18)
    ax.set_xlabel(r"Supercell size", size = fs, fontname="Nimbus Roman")
    ax.set_ylabel(r"Memory Storage (GB)", size = fs, fontname="Nimbus Roman")
    ax.tick_params(axis='both', which='both', direction='in', labelsize = fs)
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    ax.tick_params(axis='x', which='minor', length=3, width=0.8)
    ax.tick_params(axis='y', which='minor', length=3, width=0.8)
    
    ax.tick_params(axis='x', which='major', length=6, width=0.8 * 1.2)
    ax.tick_params(axis='y', which='major', length=6, width=0.8 * 1.2)
    
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.08), fontsize=18, ncol=3)
plt.show()
# Out:
# w = 0.3 has n = 2.831085223850499
# w = 0.6 has n = 2.820122951843978
# w = 0.9 has n = 2.6715737252730825

# %% [markdown]
# # Plotting scheme that combines storage and wall time

# %%
# Plot the data
omega_vals = ['0.3', '0.6', '0.9']
omega_labels = ['o', 's', '^']
supercell = [2 * i * i * i for i in range(1,5)]
basis_series = ["ccpvdz"]
color_series = ["blue", "green", "red"]


fs = 20
ms = 12

# Fitting to get the supercell size for each RI-J iteration
coeffs_per_omega_per_basis = {}
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    coeffs_per_omega = {}
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        time = rij_per_iter_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[1:])
        log_rij_per_iter = np.log(time[1:])
        coeffs = np.polyfit(log_supercell, log_rij_per_iter, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))
        coeffs_per_omega[w] = coeffs
    print("======================")
    coeffs_per_omega_per_basis[basis] = coeffs_per_omega  

# RIJ per iteration
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    for idx in range(len(omega_vals)):
        
        colors = color_series[idx]
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        ax.plot(supercell, rij_per_iter_per_omega_per_basis[basis][w], marker = marker_type, markersize=ms, color = colors, linestyle="None", label = rf"$\omega = {w}$")

        # Plot the fitting line here
        coeffs = coeffs_per_omega_per_basis[basis][w]
        natom_fit = np.linspace(0.5 * 2**3, 4 * 4**3, 40)
        time_per_iter_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]
        
        ax.plot(natom_fit, time_per_iter_fit, color = colors, linestyle="--", linewidth= 3)
        
    ax.set_xlabel(r"N$_\mathrm{atom}$", size = fs)
    ax.set_ylabel(r"Wall time (s)", size = fs)
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs, pad = 8)
    ax.set_yscale('log')
    ax.set_xscale('log')
    
    ax.set_xlim([0.9, 250])
    
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs)
    ax.tick_params(axis='y', which='major', length=5, width=1.5)
    ax.tick_params(axis='y', which='minor', length=2.5, width=0.75)
    
    ax.set_xticks([1, 10, 100])
    ax.tick_params(axis='x', which='major', length=5, width=1.5)
    ax.tick_params(axis='x', which='minor', length=2.5, width=0.75)
    

# Fitting to get the supercell size for each RI-J init time

print("==== Scale with the storage ====")
coeffs_per_omega_per_basis = {}
for ib in range(len(basis_series)):
    basis = basis_series[ib]
        
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        time = rij_init_time_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[1:])
        log_rij_per_iter = np.log(time[1:])
        coeffs = np.polyfit(log_supercell, log_rij_per_iter, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))
        coeffs_per_omega[w] = coeffs

    coeffs_per_omega_per_basis[basis] = coeffs_per_omega  

# RIJ init time vs supercell
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        colors = color_series[idx]
        marker_type = omega_labels[idx]
        ax.plot(supercell, rij_init_time_per_omega_per_basis[basis][w], marker = marker_type, color = colors, markersize=ms, linestyle="None", label = rf"$\omega = {w}$")
        
        # Plot the fitting line here
        coeffs = coeffs_per_omega_per_basis[basis][w]
        natom_fit = np.linspace(0.5 * 2**3, 4 * 4**3, 40)
        time_per_iter_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]
        
        ax.plot(natom_fit, time_per_iter_fit, color = colors, linestyle="--", linewidth= 3)
        
    ax.set_xlabel(r"N$_\mathrm{atom}$", size = fs)
    ax.set_ylabel(r"Wall time (s)", size = fs)
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs, pad = 8)
    ax.set_yscale('log')
    ax.set_xscale('log')
    
    ax.set_xlim([0.9, 250])
    
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs)
    ax.tick_params(axis='y', which='major', length=5, width=1.5)
    ax.tick_params(axis='y', which='minor', length=2.5, width=0.75)
    
    ax.set_xticks([1, 10, 100])
    ax.tick_params(axis='x', which='major', length=5, width=1.5)
    ax.tick_params(axis='x', which='minor', length=2.5, width=0.75)
    
    
# Fitting the storage data
coeffs_storage_per_omega_per_basis = {}
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    coeffs_storage_per_omega = {}
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        storage = memory_per_omega_per_basis[basis][w]
                    
        log_supercell = np.log(supercell[1:])
        log_storage = np.log(storage[1:])
        coeffs = np.polyfit(log_supercell, log_storage, 1)
        n = coeffs[0]      # scaling exponent
        print("w = " + str(w) + " has n = " + str(n))
        
        coeffs_storage_per_omega[w] = coeffs
    coeffs_storage_per_omega_per_basis[basis] = coeffs_storage_per_omega

# Converged storage at different omega
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
for ib in range(len(basis_series)):
    basis = basis_series[ib]
    
    for idx in range(len(omega_vals)):
        w = omega_vals[idx]
        marker_type = omega_labels[idx]
        colors = color_series[idx]
        ax.plot(supercell, memory_per_omega_per_basis[basis][w], color = colors, marker = marker_type, markersize = ms, linestyle="None", label = rf"$\omega = {w}$")

        # Plot the fitting line here
        coeffs = coeffs_storage_per_omega_per_basis[basis][w]
        natom_fit = np.linspace(0.5 * 2**3, 2.7 * 4**3, 40)
        time_per_iter_fit = np.exp(coeffs[1]) * natom_fit**coeffs[0]
        
        ax.plot(natom_fit, time_per_iter_fit, color = colors, linestyle="--", linewidth= 3)
        
    ax.set_xlabel(r"N$_\mathrm{atom}$", size = fs)
    ax.set_ylabel(r"Memory Storage (GB)", size = fs)
    ax.tick_params(axis='both', which='both', direction='in', labelsize = fs, pad = 8)
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    ax.set_xlim([0.9, 250])
    
    ax.set_xticks([1, 10, 100])
    ax.tick_params(axis='x', which='major', length=5, width=1.5)
    ax.tick_params(axis='x', which='minor', length=2.5, width=0.75)
        
    ax.set_yticks([1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2])
    ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2,10)*0.1, numticks=100))
    
    ax.tick_params(axis='both', which='both', direction='in', labelsize=fs)
    ax.tick_params(axis='y', which='major', length=5, width=1.5)
    ax.tick_params(axis='y', which='minor', length=2.5, width=0.75)

marker_handles = handles=[
    Line2D([0], [0], marker=omega_labels[0], color=color_series[0], markersize = ms, linestyle='None', label=r'$\omega$ = 0.3'),
    Line2D([0], [0], marker=omega_labels[1], color=color_series[1], markersize = ms, linestyle='None', label=r'$\omega$ = 0.6'),
    Line2D([0], [0], marker=omega_labels[2], color=color_series[2], markersize = ms, linestyle='None', label=r'$\omega$ = 0.9')]
# Out:
# w = 0.3 has n = 1.9245943205685307
# w = 0.6 has n = 1.6748752077598008
# w = 0.9 has n = 1.5505547347279929
# ======================
# ==== Scale with the storage ====
# w = 0.3 has n = 1.4998632047941451
# w = 0.6 has n = 1.6539592670666359
# w = 0.9 has n = 1.852905410009223
# w = 0.3 has n = 2.8310852238504967
# w = 0.6 has n = 2.8201229518439757
# w = 0.9 has n = 2.6715737252730807
